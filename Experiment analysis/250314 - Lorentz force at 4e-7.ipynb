# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import scipy.optimize as opt
import scipy.signal as scisig
import analysis_utils as au
import importlib

# %%
path = 'D:/Lab Data/lorentz_force/sphere2_20250312/20250313/Perm mag/10V/nomag ('
files = [1, 2, 3, 4, 5, 6, 7, 8, 9]
end = ').mat'
peak_height = []
PSDs = []
for i in files:
    filename = path + str(i) + end
    data = sio.loadmat(filename)
    tt = np.transpose(data['D'])[0]
    dt = data['Tinterval'][0][0]
    for i in range(int(len(tt)/10**5)):
        PSD = scisig.welch(tt[i*10**5:(i+1)*10**5], fs=1/dt, nperseg=int(1/dt/10))
        peak_height.append(PSD[1][5300])
    PSD = scisig.welch(tt, fs=1/dt, nperseg=int(1/dt/10))
    PSDs.append(PSD[1])
freq = PSD[0]

# %%
plt.plot(peak_height)
plt.yscale('log')
lb = 2000
ub = 6000
plt.figure()
for PSD in PSDs:
    plt.plot(freq[lb:ub], PSD[lb:ub], alpha = 0.5)
plt.plot(freq[lb:ub], np.mean(PSDs, axis=0)[lb:ub], 'k')
plt.yscale('log')

# %%
path = 'D:/Lab Data/lorentz_force/sphere2_20250312/20250313/Perm mag/10V/mag ('
files = [3, 4, 5]
end = ').mat'
peak_height2 = []
PSDs2 = []
for i in files:
    filename = path + str(i) + end
    data = sio.loadmat(filename)
    tt = np.transpose(data['D'])[0]
    dt = data['Tinterval'][0][0]
    for i in range(int(len(tt)/10**5)):
        PSD = scisig.welch(tt[i*10**5:(i+1)*10**5], fs=1/dt, nperseg=int(1/dt/10))
        peak_height2.append(PSD[1][5300])
    PSD = scisig.welch(tt, fs=1/dt, nperseg=int(1/dt/10))
    PSDs2.append(PSD[1])
freq = PSD[0]

# %%
plt.plot(peak_height2)
plt.yscale('log')
lb = 2000
ub = 6000
plt.figure()
for PSD in PSDs2:
    plt.plot(freq[lb:ub], PSD[lb:ub], alpha = 0.5)
plt.plot(freq[lb:ub], np.mean(PSDs2, axis=0)[lb:ub], 'k')
plt.yscale('log')

# %%
print(np.mean(peak_height))
print(np.mean(peak_height2))
# Out:
# 6.712841e-08
# 3.5204346e-07

# %%
lb = 2000
ub = 6000
plt.figure()
plt.plot(freq[lb:ub], np.mean(PSDs2, axis=0)[lb:ub], 'k', label = 'Magnet')
plt.plot(freq[lb:ub], np.mean(PSDs, axis=0)[lb:ub], 'gray', label = 'No magnet')
plt.yscale('log')
plt.legend()

# %%
path = 'D:/Lab Data/lorentz_force/sphere2_20250312/20250313/Perm mag/5V_2/nomag ('
files = [1, 2, 3, 4, 5]
end = ').mat'
peak_height = []
PSDs = []
for i in files:
    filename = path + str(i) + end
    data = sio.loadmat(filename)
    tt = np.transpose(data['D'])[0]
    dt = data['Tinterval'][0][0]
    for i in range(int(len(tt)/10**5)):
        PSD = scisig.welch(tt[i*10**5:(i+1)*10**5], fs=1/dt, nperseg=int(1/dt/10))
        peak_height.append(PSD[1][5300])
    PSD = scisig.welch(tt, fs=1/dt, nperseg=int(1/dt/10))
    PSDs.append(PSD[1])
freq = PSD[0]

# %%
plt.plot(peak_height)
plt.yscale('log')
lb = 2000
ub = 6000
plt.figure()
for PSD in PSDs:
    plt.plot(freq[lb:ub], PSD[lb:ub], alpha = 0.5)
plt.plot(freq[lb:ub], np.mean(PSDs, axis=0)[lb:ub], 'k')
plt.yscale('log')

# %%
path = 'D:/Lab Data/lorentz_force/sphere2_20250312/20250313/Perm mag/5V_2/mag ('
files = [1, 2, 3, 4, 5]
end = ').mat'
peak_height2 = []
PSDs2 = []
for i in files:
    filename = path + str(i) + end
    data = sio.loadmat(filename)
    tt = np.transpose(data['D'])[0]
    dt = data['Tinterval'][0][0]
    for i in range(int(len(tt)/10**5)):
        PSD = scisig.welch(tt[i*10**5:(i+1)*10**5], fs=1/dt, nperseg=int(1/dt/10))
        peak_height2.append(PSD[1][5300])
    PSD = scisig.welch(tt, fs=1/dt, nperseg=int(1/dt/10))
    PSDs2.append(PSD[1])
freq = PSD[0]

# %%
plt.plot(peak_height2)
plt.yscale('log')
lb = 2000
ub = 6000
plt.figure()
for PSD in PSDs2:
    plt.plot(freq[lb:ub], PSD[lb:ub], alpha = 0.5)
plt.plot(freq[lb:ub], np.mean(PSDs2, axis=0)[lb:ub], 'k')
plt.yscale('log')

# %%
print(np.mean(peak_height))
print(np.mean(peak_height2))
# Out:
# 2.1563057e-08
# 9.594381e-09

# %%
lb = 2000
ub = 6000
plt.figure()
plt.plot(freq[lb:ub], np.mean(PSDs2, axis=0)[lb:ub], 'k', label = 'Magnet')
plt.plot(freq[lb:ub], np.mean(PSDs, axis=0)[lb:ub], 'gray', label = 'No magnet')
plt.yscale('log')
plt.legend()

# %%
# So it's not obvious it's not just instabilities in the detection

# %%
#Let's try a lock-in

# %%
path = 'D:/Lab Data/lorentz_force/sphere2_20250312/20250313/Perm mag/10V/nomag ('
files = [1]
end = ').mat'
peak_height = []
PSDs = []
for i in files:
    filename = path + str(i) + end
    data = sio.loadmat(filename)
    tt = np.transpose(data['D'])[0]
    ref = np.transpose(data['F'])[0]
    dt = data['Tinterval'][0][0]

path = 'D:/Lab Data/lorentz_force/sphere2_20250312/20250313/Perm mag/10V/nomag ('
files = [9]
end = ').mat'
peak_height = []
PSDs = []
for i in files:
    filename = path + str(i) + end
    data = sio.loadmat(filename)
    tt2 = np.transpose(data['D'])[0]
    ref2 = np.transpose(data['F'])[0]
    dt = data['Tinterval'][0][0]

path = 'D:/Lab Data/lorentz_force/sphere2_20250312/20250313/Perm mag/10V/mag ('
files = [1]
end = ').mat'
peak_height = []
PSDs = []
for i in files:
    filename = path + str(i) + end
    data = sio.loadmat(filename)
    tt3 = np.transpose(data['D'])[0]
    ref3 = np.transpose(data['F'])[0]
    dt = data['Tinterval'][0][0]

path = 'D:/Lab Data/lorentz_force/sphere2_20250312/20250313/Perm mag/10V/mag ('
files = [5]
end = ').mat'
peak_height = []
PSDs = []
for i in files:
    filename = path + str(i) + end
    data = sio.loadmat(filename)
    tt4 = np.transpose(data['D'])[0]
    ref4 = np.transpose(data['F'])[0]
    dt = data['Tinterval'][0][0]

# %%
importlib.reload(au)
#1.021
time, R2, theta, R2_filt, theta_filt = au.lockin(ref-np.mean(ref), fs = int(1/dt), demod_freq = 53000, BW_pre = 0, BW = 100, BW2 = 1, mode = 'R')

time2, R22, theta2, R2_filt, theta_filt = au.lockin(ref2-np.mean(ref2), fs = int(1/dt), demod_freq = 53000, BW_pre = 0, BW = 100, BW2 = 1, mode = 'R')

time3, R23, theta3, R2_filt, theta_filt = au.lockin(ref3-np.mean(ref3), fs = int(1/dt), demod_freq = 53000, BW_pre = 0, BW = 100, BW2 = 1, mode = 'R')

time4, R24, theta4, R2_filt, theta_filt = au.lockin(ref4-np.mean(ref4), fs = int(1/dt), demod_freq = 53000, BW_pre = 0, BW = 100, BW2 = 1, mode = 'R')

# %%
demod = 2*np.sqrt(R2[1:])*np.cos(-theta+53000*2*np.pi*time[1:])
demod2 = 2*np.sqrt(R2[1:])*np.cos(-theta+53000*2*np.pi*time[1:]+np.pi/2)
tt_filt = au.butter_bandpass_filter(tt[1:], 53000-100, 53000+100, fs = int(1/dt), order = 3)
X_tt = tt_filt[:]*demod
Y_tt = tt_filt[:]*demod2
X_tt_filt = au.butter_lowpass_filter(X_tt, 10, fs = int(1/dt), order = 3)
Y_tt_filt = au.butter_lowpass_filter(Y_tt, 10, fs = int(1/dt), order = 3)
phi= np.unwrap(-2*np.arctan(X_tt_filt[1:]/Y_tt_filt[1:]))/2
R = np.sqrt(X_tt_filt[1:]**2+Y_tt_filt[1:]**2)
print(np.mean(phi[R>0.0015][100000:]))
print(np.std(phi[R>0.0015][100000:]))

demod = 2*np.sqrt(R22[1:])*np.cos(-theta2+53000*2*np.pi*time[1:])
demod2 = 2*np.sqrt(R22[1:])*np.cos(-theta2+53000*2*np.pi*time[1:]+np.pi/2)
tt_filt = au.butter_bandpass_filter(tt2[1:], 53000-100, 53000+100, fs = int(1/dt), order = 3)
X_tt = tt_filt[:]*demod
Y_tt = tt_filt[:]*demod2
X_tt_filt = au.butter_lowpass_filter(X_tt, 10, fs = int(1/dt), order = 3)
Y_tt_filt = au.butter_lowpass_filter(Y_tt, 10, fs = int(1/dt), order = 3)
phi2 = np.unwrap(-2*np.arctan(X_tt_filt[1:]/Y_tt_filt[1:]))/2
R2 = np.sqrt(X_tt_filt[1:]**2+Y_tt_filt[1:]**2)
print(np.mean(phi2[R2>0.0015][100000:]))
print(np.std(phi2[R2>0.0015][100000:]))

demod = 2*np.sqrt(R23[1:])*np.cos(-theta3+53000*2*np.pi*time[1:])
demod2 = 2*np.sqrt(R23[1:])*np.cos(-theta3+53000*2*np.pi*time[1:]+np.pi/2)
tt_filt = au.butter_bandpass_filter(tt3[1:], 53000-100, 53000+100, fs = int(1/dt), order = 3)
X_tt = tt_filt[:]*demod
Y_tt = tt_filt[:]*demod2
X_tt_filt = au.butter_lowpass_filter(X_tt, 10, fs = int(1/dt), order = 3)
Y_tt_filt = au.butter_lowpass_filter(Y_tt, 10, fs = int(1/dt), order = 3)
phi3 = np.unwrap(-2*np.arctan(X_tt_filt[1:]/Y_tt_filt[1:]))/2
R3 = np.sqrt(X_tt_filt[1:]**2+Y_tt_filt[1:]**2)
print(np.mean(phi3[R3>0.0015][100000:]))
print(np.std(phi3[R3>0.0015][100000:]))

demod = 2*np.sqrt(R24[1:])*np.cos(-theta4+53000*2*np.pi*time[1:])
demod2 = 2*np.sqrt(R24[1:])*np.cos(-theta4+53000*2*np.pi*time[1:]+np.pi/2)
tt_filt = au.butter_bandpass_filter(tt4[1:], 53000-100, 53000+100, fs = int(1/dt), order = 3)
X_tt = tt_filt[:]*demod
Y_tt = tt_filt[:]*demod2
X_tt_filt = au.butter_lowpass_filter(X_tt, 10, fs = int(1/dt), order = 3)
Y_tt_filt = au.butter_lowpass_filter(Y_tt, 10, fs = int(1/dt), order = 3)
phi4 = np.unwrap(-2*np.arctan(X_tt_filt[1:]/Y_tt_filt[1:]))/2
R4 = np.sqrt(X_tt_filt[1:]**2+Y_tt_filt[1:]**2)
print(np.mean(phi4[R4>0.0015][100000:]))
print(np.std(phi4[R4>0.0015][100000:]))
# Out:
# -0.8411762644540086
# 0.021459896873073363
# -0.8263050133822065
# 0.0144560961835483
# -0.8023686527343261
# 0.006170162252571303
# -0.8004161496030484
# 0.0052406813758049675

# %%
path = 'D:/Lab Data/lorentz_force/sphere2_20250312/20250313/Perm mag/10V/nomag ('
files = [1, 2, 3, 4, 5, 6, 7, 8, 9]
end = ').mat'

phis = []
for i in files:
    filename = path + str(i) + end
    data = sio.loadmat(filename)
    tt = np.transpose(data['D'])[0]
    ref = np.transpose(data['F'])[0]
    dt = data['Tinterval'][0][0]

    time, R2, theta, R2_filt, theta_filt = au.lockin(ref-np.mean(ref), fs = int(1/dt), demod_freq = 53000, BW_pre = 0, BW = 100, BW2 = 1, mode = 'R')
    demod = 2*np.sqrt(R2[1:])*np.cos(-theta+53000*2*np.pi*time[1:])
    demod2 = 2*np.sqrt(R2[1:])*np.cos(-theta+53000*2*np.pi*time[1:]+np.pi/2)
    tt_filt = au.butter_bandpass_filter(tt[1:], 53000-100, 53000+100, fs = int(1/dt), order = 3)
    X_tt = tt_filt[:]*demod
    Y_tt = tt_filt[:]*demod2
    X_tt_filt = au.butter_lowpass_filter(X_tt, 10, fs = int(1/dt), order = 3)
    Y_tt_filt = au.butter_lowpass_filter(Y_tt, 10, fs = int(1/dt), order = 3)
    phi= np.unwrap(-2*np.arctan(X_tt_filt[1:]/Y_tt_filt[1:]))/2
    R = np.sqrt(X_tt_filt[1:]**2+Y_tt_filt[1:]**2)
    for j in range(5):
        step = int(len(phi -100000)/5)
        phi_mean = np.mean(phi[100000+j*step:100000+(j+1)*step][R[100000+j*step:100000+(j+1)*step]>0.0015])
        phis.append(phi_mean)
print(step/10**6)

path = 'D:/Lab Data/lorentz_force/sphere2_20250312/20250313/Perm mag/10V/mag ('
files = [1, 3, 4, 5]
end = ').mat'

phis2 = []
for i in files:
    filename = path + str(i) + end
    data = sio.loadmat(filename)
    tt = np.transpose(data['D'])[0]
    ref = np.transpose(data['F'])[0]
    dt = data['Tinterval'][0][0]

    time, R2, theta, R2_filt, theta_filt = au.lockin(ref-np.mean(ref), fs = int(1/dt), demod_freq = 53000, BW_pre = 0, BW = 100, BW2 = 1, mode = 'R')
    demod = 2*np.sqrt(R2[1:])*np.cos(-theta+53000*2*np.pi*time[1:])
    demod2 = 2*np.sqrt(R2[1:])*np.cos(-theta+53000*2*np.pi*time[1:]+np.pi/2)
    tt_filt = au.butter_bandpass_filter(tt[1:], 53000-100, 53000+100, fs = int(1/dt), order = 3)
    X_tt = tt_filt[:]*demod
    Y_tt = tt_filt[:]*demod2
    X_tt_filt = au.butter_lowpass_filter(X_tt, 10, fs = int(1/dt), order = 3)
    Y_tt_filt = au.butter_lowpass_filter(Y_tt, 10, fs = int(1/dt), order = 3)
    phi= np.unwrap(-2*np.arctan(X_tt_filt[1:]/Y_tt_filt[1:]))/2
    R = np.sqrt(X_tt_filt[1:]**2+Y_tt_filt[1:]**2)
    for j in range(5):
        step = int(len(phi -100000)/5)
        phi_mean = np.mean(phi[100000+j*step:100000+(j+1)*step][R[100000+j*step:100000+(j+1)*step]>0.0015])
        phis2.append(phi_mean)
print(step/10**6)
# Out:
# 3.999999

# %%
phis_u = np.unwrap(np.array(phis)*2)/2
plt.plot(phis_u[phis_u>-1])
plt.plot(phis_u[phis_u>-1]+np.std(phis_u[phis_u>-1]))
plt.plot(phis_u[phis_u>-1]-np.std(phis_u[phis_u>-1]))
plt.plot(phis2)
plt.plot(phis2+np.std(phis2))
plt.plot(phis2-np.std(phis2))

# %%
np.std(phis2)
# Out:
# 0.001893559198560823

# %%
plt.plot(phi[100000:1500*10000:1000])
plt.plot(phi2[100000:1500*10000:1000])
plt.plot(phi3[100000:1500*10000:1000])
plt.plot(phi4[100000:1500*10000:1000])
plt.ylim(-0.9, -0.7)
plt.figure()
plt.plot(R[100000:1500*10000:1000])
plt.plot(R2[100000:1500*10000:1000])
plt.plot(R3[100000:1500*10000:1000])
plt.plot(R4[100000:1500*10000:1000])

# %%
demod = 2*np.sqrt(R2[1:])*np.cos(-theta+53000*2*np.pi*time[1:])
demod2 = 2*np.sqrt(R2[1:])*np.cos(-theta+53000*2*np.pi*time[1:]+np.pi/2)
tt_filt = au.butter_bandpass_filter(tt[1:], 53000-1000, 53000+1000, fs = int(1/dt), order = 3)
X_tt = tt_filt[:]*demod
Y_tt = tt_filt[:]*demod2
X_tt_filt = au.butter_lowpass_filter(X_tt, 10, fs = int(1/dt), order = 3)
Y_tt_filt = au.butter_lowpass_filter(Y_tt, 10, fs = int(1/dt), order = 3)
phi= np.unwrap(-2*np.arctan(X_tt_filt[1:]/Y_tt_filt[1:]))/2
print(np.mean(phi))
print(np.std(phi))
# Out:
# -0.9184300745545616
# 0.4218032162518568

# %%
plt.plot(X_tt_filt[100000::10000])
plt.plot(Y_tt_filt[100000::10000])

# %%
print(np.mean(phi[:7500000]))
print(np.std(phi[:7500000]))
# Out:
# -0.8632722443871015
# 0.040239259541894924

# %%
# test

# %%
ub = 1000000
test_sig = np.sin(53000*2*np.pi*time[:ub])
test_sig2 = 0.1*np.sin(53000*2*np.pi*time[:ub]+np.pi/2)

# %%
plt.plot(test_sig[:100])
plt.plot(test_sig2[:100])
plt.plot(test_sig[:100]+test_sig2[:100])

# %%
PSD_test = scisig.welch(test_sig, fs=1/dt, nperseg=int(1/dt/1000))
PSD_test2 = scisig.welch(test_sig2, fs=1/dt, nperseg=int(1/dt/1000))
PSD_test3 = scisig.welch(test_sig+test_sig2, fs=1/dt, nperseg=int(1/dt/1000))

# %%
plt.plot(PSD_test[0], PSD_test[1])
plt.plot(PSD_test2[0], PSD_test2[1])
plt.plot(PSD_test3[0], PSD_test3[1])
#plt.yscale('log')
plt.ylim(10**-10, 10**-3)
plt.xlim(52500, 53500)
# Out:
# (52500.0, 53500.0)

# %%
phaseshifts = np.linspace(0, 2*np.pi, 100)+np.pi/2
av_X = []
av_X2 = []
for phaseshift in phaseshifts:
    demod = np.sin(53000*2*np.pi*time[:ub]+phaseshift)
    X_tt = (test_sig+test_sig2)*demod
    X_tt_filt = au.butter_lowpass_filter(X_tt, 10, fs = int(1/dt), order = 3)
    av_X.append(np.mean(X_tt_filt[300000:]))
    X_tt = (test_sig)*demod
    X_tt_filt2 = au.butter_lowpass_filter(X_tt, 10, fs = int(1/dt), order = 3)
    av_X2.append(np.mean(X_tt_filt2[300000:]))

# %%
plt.plot(X_tt_filt)
plt.plot(X_tt_filt2)

# %%
plt.plot(phaseshifts, av_X)
plt.plot(phaseshifts, av_X2)
