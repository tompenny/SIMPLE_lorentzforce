# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Have now learnt we can use flat wire to make coils. This means we can fit way more in. Also want to consider putting coils outside of chamber. Let's start with just one big coil above the trap. Doing 20 turns is very reasonable here (that's what they have in Haystack) so let's start with that.

# %%
u0 = 4*np.pi*10**(-7) # Magnetic permiability 
I = 10 # Current
R = np.linspace(4*10**(-2), 50*10**(-2)) # Range of coil radii to try 
z = 6*10**(-2)
n = 20

# %%
B = 20*u0*I*R**2/2/(R**2+z**2)**(3/2)/10**(-4) # field from coil n0

# %%
plt.plot(R*100, B, 'o')
plt.ylabel('Magnetic field (G)')
plt.xlabel('Coil radius (cm)')
# Out:
# Text(0.5, 0, 'Coil radius (cm)')

# %%
np.sqrt(10**2+5**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 np.sqrt(10**2+5**2)
#
# NameError: name 'np' is not defined

# %%
z = 6*10**(-2) # Distance from particle
ns = range(1, 200, 1)
R0l = np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50])*10**(-2)
B3 = []
for R0 in R0l:
    B2 = [] # Magnetic field for each max coil number
    for n in ns:
        B_tmp2 = 0
        for n0 in range(n):
            B_tmp = u0*I*(R0+(n0)*0.5*10**(-3))**2/2/((R0+(n0)*0.5*10**(-3))**2+z**2)**(3/2)/10**(-4) # Magnetic field from coil n0
            B_tmp2 += B_tmp
        B2.append(B_tmp2)
        if n == 20:
            B3.append(B_tmp2)
    plt.plot(ns, B2, 'o', label = str(R0*100) +" cm")
plt.ylabel('B field (G)')
plt.xlabel('Number of coils')
plt.legend()

# %%
ns = range(1, 120, 1)
L = 2*np.pi*sum(5*10**(-2)+np.array(ns)*0.5*10**(-3))
Res = L/300*1.317
Pdisp = I**2*Res
print(L)
print(Pdisp)
# Out:
# 59.81592412434965
# 26.259190690589495

# %%
0.5*10**(-3)*200+0.05
# Out:
# 0.15000000000000002

# %%
Res*10
# Out:
# 2.04805137476499

# %%
5*10**(-2)+250*0.5*10**(-3)
# Out:
# 0.175

# %%
# Blue is an approximation assuming all coils are in same place
# Orange is an exact calculation
# One can see the approximation is pretty good

plt.plot(R*100, B, 'o')
plt.plot((R0l+10*0.0005)*100, B3, 'o')
plt.ylabel('Magnetic field (G)')
plt.xlabel('Coil radius (cm)')
# Out:
# Text(0.5, 0, 'Coil radius (cm)')

# %% [markdown]
# Now two from the side in Helmholtz config

# %%
u0 = 4*np.pi*10**(-7) # Magnetic permiability 
I = 10 # Current
R = np.linspace(2.5*10**(-2), 4.0*10**(-2)) # Range of coil radii to try 
z = 9*10**(-2)
n = 20

# %%
B = 2*20*u0*I*R**2/2/(R**2+z**2)**(3/2)/10**(-4) # field from coil n0

# %%
plt.plot(R*100, B, 'o')
plt.ylabel('Magnetic field (G)')
plt.xlabel('Coil radius (cm)')
# Out:
# Text(0.5, 0, 'Coil radius (cm)')

# %%
z = 9*10**(-2) # Distance from particle
ns = range(1, 40, 1)
R0l = np.array([2])*10**(-2)
B3 = []
for R0 in R0l:
    B2 = [] # Magnetic field for each max coil number
    for n in ns:
        B_tmp2 = 0
        for n0 in range(n):
            B_tmp = u0*I*(R0+(n0)*0.5*10**(-3))**2/2/((R0+(n0)*0.5*10**(-3))**2+z**2)**(3/2)/10**(-4) # Magnetic field from coil n0
            B_tmp2 += B_tmp
        B2.append(2*B_tmp2) # factor 2 for Helmholtz
        if n == 20:
            B3.append(B_tmp2)
    plt.plot(ns, B2, 'o', label = str(R0*100) +" cm")
plt.ylabel('B field (G)')
plt.xlabel('Number of coils')
plt.legend()

# %%
2*10**(-2)+0.5*10**(-3)*40
# Out:
# 0.04

# %% [markdown]
# # AC magnetic field

# %%
# For a single loop how big/small till we get 1 ohm reactance at 20 Hz (this is what our power amplifier can do)?

u0 = 4*np.pi*10**(-7) # Magnetic permiability 
P = 10000
R = np.linspace(4*10**(-2), 25000*10**(0)) # Range of coil radii to try 
f = 20

L = (u0*np.pi*R/2*np.sqrt(P/f/2/np.pi))**(2/3)

I = np.sqrt(P/2/np.pi/f/L)
B = u0*I/2/R

# %%
plt.plot(R, L)
plt.plot(R, B)
plt.yscale('log')
plt.xscale('log')

# %%
# 25 km??? Seems crazy
